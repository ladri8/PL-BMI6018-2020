# %% [markdown]
# # Assignment 5

# %% [markdown]
# ## Question 1 (12 points)
#
# <b> Consider you have three companies (named Company_1, Company_2, and Company_3). Each company has 3 employees and each employee has the data or attribues (Name,Age, Absence) of data types (string, float, and a tuple of 3 integers).  See the distribution of the codes' points in the below code.</b>
#
# ### Example (See the below Table 1):
#
# <b> Company_1 has three employees: </b>
# 1. Their Names: 'R1', 'R2', and 'R3'
# 2. Their Ages: 30, 25, and 40
# 3. Their Absence tuples: (1,2,5), (2,4,1), and (4,5, 7)
# 4. Index 0 of Names corresponds to the index 0 of Ages and Absence. So employee with name 'R1' has age 30 and the absences (1,2,5)
#
# <b> Write a program that takes as inputs the above data for the three employees and prints the name of each company and the names of their respective employees who have the largest age and the minimum average of absent days. </b>
#
#
# <b> You are required to do the following </b>.
# 1. Create an abstract class Company and abstract methods using ABC and @abstractmethod:
#     - The constructor that puts or initiates the atrribute myData with a dictionary input myDict with three keys 'Name', 'Age', and 'Absence' with the values of lists of names, ages, and absences respectively.
#     - An abstract method named find_the_maximum_age.
#     - An abstract method named find_the_minimum_average_absence.
# 2. Create a class named realCompany that inherits the Company constructor/abstract methods and overrides the abstract methods such that:
#     - Implements the body of find_the_maximum_age and returns the name of employee and the corresponding age for the employee who has the maximum age among all employees.
#     - Implements the body of find_the_minimum_average_absence and returns the name of employee and the corresponding tuple of absense for the employee who has the minimum average of absent days.
# 3. Define the function, named the_maximum_age that takes a list of three realCompany objects, uses the find_the_maximum_age method of each object and return (the name of company, the name of employee, the coressponding age of the employee who has the maximum age among all employees in all companies).
# 4. Define the function, named the_minimum_average_absence that takes a list of three realCompany objects, uses the find_the_minimum_average_absence method of each object to return (the name of company, the name of employee, the coressponding age of the employee who has the maximum age among all employees in all companies).
# 5. Create the three realCompany objects, named Company_1, Company_2, Company_3 with three dictionaries that present their data.
#     - For example, to create Company_1 data, use the following statement:
#          - Company_1=realCompany({'Name':['R1','R2','R3'], 'Age':[30,25,40], 'Absence':[(1,2,5),(2,4,1), (4,5,7)]})
# 6. Create a list named L of three companies objects.
# 7. Print the results of calling the_maximum_age (L) function. In our example, it should print the name of the company is  company_3 and the name of the employee is M3 with the age is 68.
# 8. Print the results of calling the_minimum_average_absence (L) function. In our example, it should print the name of the company is company_2 and company_3 and the name of the employee is S2 and M1 with the minimum absence record of (2,2,2) and (2,1,3).
#
#
# <b> Your code should be generic that takes takes any names and numbers of ages/record absences. The below is the data table and the program code that you need to fill </b>

# %% [markdown]
# ### Data Table
#
# ![image.png](attachment:image.png)

# %%
# Fill in the below code skeleton

from abc import ABC, abstractmethod

class Company(ABC):     # 1 point
     
    # Complete the constructor to input the dictionary of the data as mentioned above and put it in myData.    
    def __init__(self,value):
        
    #define two abstract methods 
    def find_the_maximum_age (self):
    
    def find_the_minimum_average_absence (self):

class realCompany(Company): # 4 points
    #override the above Company two methods:find_the_maximum_age, and find_the_minimum_average_absence

def the_maximum_age(L): # 3 points
    # L is the list of the three realCompany objects
    # implement the statments that use the find_the_maximum_age method of each object. 
    # return (the name of company, the name of employee, the coressponding age of the employee who has the maximum age among all employees in all companies).

def the_minimum_average_absence(L) # 3 points 
    # L is the list of the three realCompany objects
    # implement the statments that use the find_the_minimum_average_absence method of each object.
    # return (the name of company, the name of employee, the coressponding age of the employee who has the maximum age among all employees in all companies).

#Create the list L of the three realCompany objects with their dictionaries. # 1 point.

print(the_maximum_age(L))
print(the_minimum_average_absence(L))
