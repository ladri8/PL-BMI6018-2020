# %% [markdown]
# ## Revision
#
# 1. Function definition.
# 2. Function call.
# 3. Return within the loop.
# 4. Modules for the project.
# 5. Recursive tree and stack.

# %%
def funnyFun():
    for i in range(10):
        print (i*i)
#for i in range(1):    
#print(funnyFun(1))

print(funnyFun())
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# None

# %%
def funnyFun():
    return (3*3)

x=funnyFun
print(x())
# Out:
# 9

# %% [markdown]
# ### [Operator Overloading](https://thepythonguru.com/python-operator-overloading/)
#
#
# <b> In computer programming, operator overloading, sometimes termed operator <u> ad hoc polymorphism, is a specific case of polymorphism </u>, where different operators have different implementations depending on their arguments. Operator overloading is generally defined by a programming language, a programmer, or both. </b>[1]
#
# You have already seen you can use + operator for adding numbers and at the same time to concatenate strings. It is possible because + operator is overloaded by both int class and str class. The operators are actually methods defined in respective classes.
#
#
# Following table lists some generic functionality that you can override in your own classes:−
#
#
# ![image.png](attachment:image.png)
#
#
#
#
# [1]: https://en.wikipedia.org/wiki/Operator_overloading

# %%
class Vector:
    def __init__(self, a, b):
        self.a = a
        self.b = b

    def __str__(self):
        return 'Vector (%d, %d)' % (self.a, self.b)
   
    def __add__(self,other):
        return Vector(self.a + other.a, self.b + other.b)

v1 = Vector(2,10)
v2 = Vector(5,-2)
print(v1 + v2)
# Out:
# Vector (7, 8)

# %%
import math
 
class Circle:
 
    def __init__(self, radius):
        self.__radius = radius
 
    def setRadius(self, radius):
        self.__radius = radius
 
    def getRadius(self):
        return self.__radius
 
    def area(self):
        return math.pi * self.__radius ** 2
 
    def __add__(self, another_circle):
        return Circle( self.__radius + another_circle.__radius )
 
    def __gt__(self, another_circle):
        return self.__radius > another_circle.__radius
 
    def __lt__(self, another_circle):
        return self.__radius < another_circle.__radius
 
    def __str__(self):
        return "Circle with radius " + str(self.__radius)

c1 = Circle(4)
print(c1.getRadius())
 
c2 = Circle(5)
print(c2.getRadius())
 
c3 = c1 + c2
print(c3.getRadius())
 
print( c3 > c2) # Became possible because we have added __gt__ method
 
print( c1 < c2) # Became possible because we have added __lt__ method
 
print(c3) # Became possible because we have added __str__ method
# Out:
# 4
# 5
# 9
# True
# True
# Circle with radius 9

# %% [markdown]
# ## [Polymorphism](https://www.programiz.com/python-programming/polymorphism)
#
# <b> What is Polymorphism : The word polymorphism means having many forms. In programming, polymorphism means same function name (but different signatures) being uses for different types. </b> [1]
#
# [1]: https://www.geeksforgeeks.org/polymorphism-in-python/

# %%
#len with s string

print(len('BMI6018'))


#len with a list
print(len([1,6,7]))
# Out:
# 7
# 3

# %%
# A simple Python function to demonstrate  
# Polymorphism 
  
def add(x, y, z = 0):  
    return x + y+z 
  
# Driver code  
print(add(2, 3)) 
print(add(2, 3, 4))
# Out:
# 5
# 9

# %% [markdown]
# ## Polymorphism in classes
#
# ### Example Car-Truck-SportsCar
#
# ![image.png](attachment:image.png)

# %%
class Car:
    def __init__(self, name):
        self.name = name
    
    def drive(self):
        raise NotImplementedError("Subclass must implement abstract method")

    def stop(self):
        raise NotImplementedError("Subclass must implement abstract method")
    
class Sportscar(Car):
    def drive(self):
        return 'Sportscar driving!'

    def stop(self):
        return 'Sportscar braking!'
    
class Truck(Car):
    def drive(self):
        return 'Truck driving slowly because heavily loaded.'

    def stop(self):
        return 'Truck braking!'

cars = [Truck('Bananatruck'),
Truck('Orangetruck'),
Sportscar('Z3')]

for car in cars:
    print(car.name + ': ' + car.drive())
# Out:
# Bananatruck: Truck driving slowly because heavily loaded.
# Orangetruck: Truck driving slowly because heavily loaded.
# Z3: Sportscar driving!

# %%
class India(): 
    def capital(self): 
        print("New Delhi is the capital of India.") 
   
    def language(self): 
        print("Hindi is the most widely spoken language of India.") 
   
    def type(self): 
        print("India is a developing country.") 

class USA(): 
    def capital(self): 
        print("Washington, D.C. is the capital of USA.") 
   
    def language(self): 
        print("English is the primary language of USA.") 
   
    def type(self): 
        print("USA is a developed country.") 

def func(obj): 
    obj.capital() 
    obj.language() 
    obj.type() 
    
obj_ind = India() 
obj_usa = USA() 
   
func(obj_ind) 
func(obj_usa)
# Out:
# New Delhi is the capital of India.
# Hindi is the most widely spoken language of India.
# India is a developing country.
# Washington, D.C. is the capital of USA.
# English is the primary language of USA.
# USA is a developed country.

# %% [markdown]
# ## [Abstraction in OOP](https://whatis.techtarget.com/definition/abstraction#:~:text=In%20object%2Doriented%20programming%2C%20abstraction,reduce%20complexity%20and%20increase%20efficiency.)
#
# An abstract class can be considered as a blueprint for other classes. It allows you to create a set of methods that must be created within any child classes built from the abstract class. A class which contains one or more abstract methods is called an abstract class. An abstract method is a method that has a declaration but does not have an implementation. While we are designing large functional units we use an abstract class. When we want to provide a common interface for different implementations of a component, we use an abstract class.
#
#  A concrete class which is a sub class of such abstract base class then implements the abstract base by overriding its abstract methods. The abc module defines ABCMeta class which is a metaclass for defining abstract base class.
#
# #### [Examples](https://www.geeksforgeeks.org/abstract-classes-in-python/)

# %%
import abc
help(abc)

#Python documentation https://docs.python.org/3/library/abc.html
# Out:
# Help on module abc:
#
# NAME
#     abc - Abstract Base Classes (ABCs) according to PEP 3119.
#
# MODULE REFERENCE
#     https://docs.python.org/3.7/library/abc
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# CLASSES
#     builtins.classmethod(builtins.object)
#         abstractclassmethod
#     builtins.object
#         ABC
#     builtins.property(builtins.object)
#         abstractproperty
#     builtins.staticmethod(builtins.object)
#         abstractstaticmethod
#     builtins.type(builtins.object)
#         ABCMeta
#
#     class ABC(builtins.object)
#      |  Helper class that provides a standard way to create an ABC using
#      |  inheritance.
#      |
# ...

# %%
#Example 1

# Python program showing 
# abstract base class work 
  
#from abc import ABC
  
class Polygon(ABV):  
    #abstract method 
    def noofsides(self): 
        pass

class Triangle(Polygon):   
    # overriding abstract method 
    def noofsides(self): 
        print("I have 3 sides") 

class Pentagon(Polygon):   
    # overriding abstract method 
    def noofsides(self): 
        print("I have 5 sides") 

class Hexagon(Polygon): 
    # overriding abstract method 
    def noofsides(self): 
        print("I have 6 sides") 

class Quadrilateral(Polygon):   
    # overriding abstract method 
    def noofsides(self): 
        print("I have 4 sides") 

# Driver code 


R = Triangle() 
R.noofsides() 
  
K = Quadrilateral() 
K.noofsides() 
  
R = Pentagon() 
R.noofsides() 
  
K = Hexagon() 
K.noofsides()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-cefaf286e10b> in <module>
#       6 #from abc import ABC
#       7
# ----> 8 class Polygon(ABV):
#       9     #abstract method
#      10     def noofsides(self):
#
# NameError: name 'ABV' is not defined

# %%
# Python program showing 
# abstract base class work 
  
from abc import ABC
class Animal(ABC):   
    def move(self): 
        pass

class Human(Animal):   
    def move(self): 
        print("I can walk and run") 

class Snake(Animal):   
    def move(self): 
        print("I can crawl") 

class Dog(Animal):   
    def move(self): 
        print("I can bark") 

class Lion(Animal):  
    def move1(self): 
        print("I can roar") 
          

# Driver code 
A=Animal()
A.move()
R = Human() 
R.move() 
  
K = Snake() 
K.move() 
  
R = Dog() 
R.move() 
  
K = Lion() 
K.move1()
# Out:
# I can walk and run
# I can crawl
# I can bark
# I can roar

# %%
# Python program showing 
# implementation of abstract 
# class through subclassing 
  
#import abc 
  
class parent:        
    def mymethod(self): 
        pass

class child(parent): 
    def mymethod(self): 
        print("child class") 

# Driver code 
print( issubclass(child, parent)) 
print( isinstance(child(), parent))
# Out:
# True
# True

# %%
# Python program invoking a  
# method using super() 

import abc
from abc import ABC #, abstractmethod 
  
class R(ABC): 
    def rk(self): 
        print("Abstract Base Class") 

class K(R): 
    def rk(self): 
        super().rk() 
        print("subclass ") 

# Driver code 
r = K() 
r.rk()
# Out:
# Abstract Base Class
# subclass

# %% [markdown]
# ## OOP:
#
# 1. Every things in Python OOP.
# 2. OOP --> inheritence.
# 3. Object encapsulates data/methods.
# 4. method overriding (Parent/Child)
# 5. method polymorphism (2 or more methods have the same name with different implementation).
# 6. Constructor and destructor.
# 7. Abstraction.
# 8. Operator Overloading.
# 9. multilevel inheritence.
# 10. Object && metaclass
# 11. Some important methods (issubclass,.. mro).
# 12. init, maybe del, for each attribute (data variable) get and set..
# 13. The class attribute..

# %% [markdown]
# ## Functional programming
#
# ### Structure of functions of functions or functions.
#
# 1. The function structure:
#     - function definition has paramters or arguments (astriks). It include the body.
#     - It can have return statement but not necessary.
#     -  Any datatype including objects, functions, built-in datatypes as arguments and/or for returm.
# 2. Using functions during loop..

# %% [markdown]
# ## [Decorators in Python](https://www.python-course.eu/python3_decorators.php)
#
#
# A decorator is a design pattern in Python that allows a user to add new functionality to an existing object without modifying its structure.

# %% [markdown]
# ### Function decorators

# %%
#Assigning Functions to Variables

def square_num(number):
    return number*number

square_num1 = square_num
square_num1(5)
# Out:
# 25

# %%
## Defining Functions Inside other Functions

def squares(number):
    def square_num(number):
        return number*number
    
    result=square_num(number)
    return result

squares(5)
# Out:
# 25

# %%
# Passing Functions as Arguments to other Functions

def square_num(number):
    return number*number

def function_call (function):
    a_number=int(input('a number: '))
    return function(a_number)

function_call(square_num)
# Out:
# a number: 4
# 16

# %% [markdown]
# ## [Creating Function Decorators](https://www.geeksforgeeks.org/function-wrappers-in-python/)
#
# Wrappers around the functions are also knows as decorators which are a very powerful and useful tool in Python since it allows programmers to modify the behavior of function or class. Decorators allow us to wrap another function in order to extend the behavior of the wrapped function, without permanently modifying it. In Decorators, functions are taken as the argument into another function and then called inside the wrapper function.
#
# [Next Example](https://www.datacamp.com/community/tutorials/decorators-python?utm_source=adwords_ppc&utm_campaignid=1565261270&utm_adgroupid=67750485268&utm_device=c&utm_keyword=&utm_matchtype=b&utm_network=g&utm_adpostion=&utm_creative=295208661496&utm_targetid=aud-299261629574:dsa-429603003980&utm_loc_interest_ms=&utm_loc_physical_ms=9029768&gclid=CjwKCAiA-f78BRBbEiwATKRRBJj-62hUj8CNTT0axcl7dkaLA3C-lsgtsMef-ZFgrksr520BnOv4yxoC_qIQAvD_BwE)

# %%
def uppercase_decorator(function):
    def wrapper():
        func = function()
        make_uppercase = func.upper()
        return make_uppercase

    return wrapper

def say_hi():
    return 'hello there'

decorate = uppercase_decorator(say_hi)
decorate()
# Out:
# 'HELLO THERE'

# %% [markdown]
# # [Class Decorator](https://dev.to/apcelent/python-decorator-tutorial-with-example-529f)

# %%
class Power(object):
    def __init__(self, arg):
        self._arg = arg

    def __call__(self, a, b):
        retval = self._arg(a, b)
        return retval ** 2


@Power
def multiply_together(a, b):
    return a * b


print(multiply_together)
print(multiply_together(2, 2))
# Out:
# ...
# 16

# %% [markdown]
# ## [Attributes and Properties](https://www.geeksforgeeks.org/difference-between-attributes-and-properties-in-python/)
#
#
# Class Attribute: Class Attributes are unique to each class. Each instance of the class will have this attribute.
#
# Instance Attribute: Instance Attributes are unique to each instance, (an instance is another name for an object). Every object/instance has its own attribute and can be changed without affecting other instances.
#
#
# Properties are special kind of attributes. It has getter, setter and delete methods like __get__, __set__ and __delete__ methods.

# %%
# declare a class 
class Employee:  
    
    # class attribute 
    count = 0      
        
    # define a method 
    def increase(self):  
        Employee.count += 1
    
# create an Employee  
# class object 
a1 = Employee()  
  
# calling object's method 
a1.increase()  
  
# print value of class attribute 
print(a1.count)  
     
a2 = Employee()  
  
a2.increase()  
  
print(a2.count)  
    
print(Employee.count)
# Out:
# 1
# 2
# 2

# %%
# create a class 
class Employee:  
    
    # constructor 
    def __init__(self):  
        
        # instance attribute 
        self.name = 'Gfg'
        self.salary = 4000
    
    # define a method 
    def show(self):  
        print(self.name)  
        print(self.salary)  

# create an object of  
# Employee class 
x = Employee() 
  
# method calling 
x.show()
# Out:
# Gfg
# 4000

# %%
#Properties
# create a class 
class byDeco:  
    
   # constructor 
    def __init__(self, value):  
        self._value = value  
            
    # getting the values 
    @property              
    def value(self):  
        print('Getting value')  
        return self._value  
            
    # setting the values      
    @value.setter  
    def value(self, value):  
        print('Setting value to ' + value)  
        self._value = value  
            
    # deleting the values  
    @value.deleter  
    def value(self):  
        print('Deleting value')  
        del self._value  
    
    
# create an object of class 
x = byDeco('happy Coding')  
print(x.value)  
    
x.value = 'Hey Coder!'
    
# deleting the value 
del x.value
# Out:
# Getting value
# happy Coding
# Setting value to Hey Coder!
# Deleting value

# %%
# Abstract classes includes attributes in addition to methods, you can require the attributes in concrete classes by defining them with @abstractproperty

# Python program showing 
# abstract properties 
  
import abc 
from abc import ABC, abstractmethod 
  
class parent(ABC): 
    @abc.abstractproperty 
    def mymethod(self): 
        return "parent class"

class child(parent):    
    @property
    def mymethod(self): 
        return "child class"

try: 
    r =parent() 
    print(r.mymethod) 
except Exception as err: 
    print (err) 

r = child() 
print (r.mymethod)
# Out:
# Can't instantiate abstract class parent with abstract methods mymethod
# child class

# %%
# Python program showing 
# abstract class cannot 
# be an instantiation 
from abc import ABC,abstractmethod 
  
class Animal(ABC): 
    @abstractmethod
    def move(self): 
        pass
class Human(Animal): 
    def move(self): 
        print("I can walk and run") 

class Snake(Animal): 
    def move(self): 
        print("I can crawl") 

class Dog(Animal): 
    def move(self): 
        print("I can bark") 

class Lion(Animal): 
    def move(self): 
        print("I can roar") 

C=Animal()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-dcc7f76a5889> in <module>
#      24         print("I can roar")
#      25
# ---> 26 C=Animal()
#
# TypeError: Can't instantiate abstract class Animal with abstract methods move
